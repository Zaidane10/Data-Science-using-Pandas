# %% [markdown]
# ### Module 2
# ### Session 2
# ### Data Cleaning

# %%
import pandas as pd

# %%
laptops = pd.read_csv('laptops.csv', encoding = 'Windows-1251')

# %%
laptops
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %%
laptops.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
laptops.columns = laptops.columns.str.strip().str.replace('(', '').str.replace(')','').str.lower().str.replace(' ','_')\
.str.replace('operating_system','os')       #Replacing Caps with lower case and spaces with _

# %%
laptops.columns
# Out:
# Index(['manufacturer', 'model_name', 'category', 'screen_size', 'screen',
#        'cpu', 'ram', 'storage', 'gpu', 'os', 'os_version', 'weight',
#        'price_euros'],
#       dtype='object')

# %%
laptops["screen_size"] = laptops["screen_size"].str.strip('"').astype(float) 

#eliminating " sign from inches and typecasting

# %%
laptops["screen_size"]
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1298    14.0
# 1299    13.3
# 1300    14.0
# 1301    15.6
# 1302    15.6
# Name: screen_size, Length: 1303, dtype: float64

# %%
#laptops = laptops.rename({"screen_size":"screen_size_inches"}, axis=1)

laptops.rename({"screen_size":"screen_size_inches"}, axis=1, inplace= True)   #inplace updates the environment where its working

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
laptops["screen_size_inches"].mean()
# Out:
# 15.017191097467379

# %%
#Avg Screen size is 15inches

# %%
laptops["weight"] = laptops["weight"].str.strip("kg").str.strip("kgs").astype(float)

# %%
laptops.rename({"weight":"weight_kg"}, axis=1, inplace= True)

# %%
laptops["weight_kg"]
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: weight_kg, Length: 1303, dtype: float64

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
laptops["weight_kg"].mean()
# Out:
# 2.0387336914811973

# %%
#Avg weight is around 2kgs

# %%
laptops["price_euros"] = laptops["price_euros"].str.replace(",",".").astype(float)

# %%
laptops["price_euros"]
# Out:
# 0       1339.69
# 1        898.94
# 2        575.00
# 3       2537.45
# 4       1803.60
#          ...
# 1298     638.00
# 1299    1499.00
# 1300     229.00
# 1301     764.00
# 1302     369.00
# Name: price_euros, Length: 1303, dtype: float64

# %%
laptops["price_euros"].mean()
# Out:
# 1123.6869915579432

# %%
#Avg price is around 1125 euros

# %%
laptops["ram"] = laptops["ram"].str.strip("GB").astype(float)

# %%
laptops["ram"]
# Out:
# 0        8.0
# 1        8.0
# 2        8.0
# 3       16.0
# 4        8.0
#         ...
# 1298     4.0
# 1299    16.0
# 1300     2.0
# 1301     6.0
# 1302     4.0
# Name: ram, Length: 1303, dtype: float64

# %%
laptops["ram"].mean()
# Out:
# 8.382194934765925

# %%
#Avg RAM size is 8GB

# %%
gpu_split = laptops["gpu"].str.split(n=1, expand=True)   #splits from 1st space    #splits in 2 different columns

# %%
laptops["gpu_company"] = gpu_split[0]
laptops["gpu_model"] = gpu_split[1]

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
laptops["gpu_company"].value_counts()
# Out:
# gpu_company
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
laptops["gpu_company"].value_counts(normalize=True)*100
# Out:
# gpu_company
# Intel     55.410591
# Nvidia    30.698388
# AMD       13.814275
# ARM        0.076746
# Name: proportion, dtype: float64

# %%
laptops_gpu = laptops[(laptops["gpu_company"] != "Intel") & (laptops["gpu_company"] != "ARM")]

# %%
laptops_gpu["gpu_company"].value_counts(normalize=True)*100
# Out:
# gpu_company
# Nvidia    68.965517
# AMD       31.034483
# Name: proportion, dtype: float64

# %%
laptops_gpu["gpu_model"].value_counts()
# Out:
# gpu_model
# GeForce GTX 1050    66
# GeForce GTX 1060    48
# GeForce 940MX       43
# Radeon 530          41
# GeForce GTX 1070    30
#                     ..
# Quadro M620M         1
# Radeon R5 520        1
# Radeon R7            1
# Radeon 540           1
# GeForce 960M         1
# Name: count, Length: 86, dtype: int64

# %%
cpu_split = laptops["cpu"].str.split(n=1, expand= True)

# %%
laptops["cpu_company"] = cpu_split[0]
laptops["cpu_model"] = cpu_split[1]

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
laptops["cpu_company"].value_counts(normalize= True)*100
# Out:
# cpu_company
# Intel      95.165004
# AMD         4.758250
# Samsung     0.076746
# Name: proportion, dtype: float64

# %%
laptops["cpu_model"].value_counts()
# Out:
# cpu_model
# Core i5 7200U 2.5GHz       190
# Core i7 7700HQ 2.8GHz      146
# Core i7 7500U 2.7GHz       134
# Core i7 8550U 1.8GHz        73
# Core i5 8250U 1.6GHz        72
#                           ...
# Core M M3-6Y30 0.9GHz        1
# A9-Series 9420 2.9GHz        1
# Core i3 6006U 2.2GHz         1
# A6-Series 7310 2GHz          1
# Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %% [markdown]
# ### Hence its prefereable to include following specs
# 1) Nvidia company gpu
# 2) GeForce GTX 1050 or GeForce GTX 1060 gpu model
# 3) 8GB RAM
# 4) Intel processor with speed > 2GHz
# 5) ~15inches screen size
# 6) 2kgs weight
# 7) Price of 1125 Euros

# %%
laptops["os"].unique()
# Out:
# array(['macOS', 'No OS', 'Windows', 'Mac OS', 'Linux', 'Android',
#        'Chrome OS'], dtype=object)

# %%
#laptops["os"].str.replace("Mac OS", "mac OS")

laptops.loc[laptops["os"] == "Mac OS", "os"]
# Out:
# 6       Mac OS
# 26      Mac OS
# 34      Mac OS
# 794     Mac OS
# 1069    Mac OS
# 1193    Mac OS
# 1210    Mac OS
# 1234    Mac OS
# Name: os, dtype: object

# %%
laptops.loc[laptops["os"] == "Mac OS", "os"] = "macOS"     #Alternate way of replacing by first accessing and then using loc

# %%
laptops["os"].unique()
# Out:
# array(['macOS', 'No OS', 'Windows', 'Linux', 'Android', 'Chrome OS'],
#       dtype=object)

# %%
laptops["os"].value_counts()
# Out:
# os
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          21
# Android         2
# Name: count, dtype: int64

# %% [markdown]
# ### Missing values

# %%
laptops.isnull().sum()
# Out:
# manufacturer            0
# model_name              0
# category                0
# screen_size_inches      0
# screen                  0
# cpu                     0
# ram                     0
# storage                 0
# gpu                     0
# os                      0
# os_version            170
# weight_kg               0
# price_euros             0
# gpu_company             0
# gpu_model               0
# cpu_company             0
# cpu_model               0
# dtype: int64

# %%
laptops.loc[laptops["os_version"].isnull()]
# Out:
#      manufacturer      model_name   category  screen_size_inches  \
# 0           Apple     MacBook Pro  Ultrabook                13.3
# 1           Apple     Macbook Air  Ultrabook                13.3
# 2              HP          250 G6   Notebook                15.6
# 3           Apple     MacBook Pro  Ultrabook                15.4
# 4           Apple     MacBook Pro  Ultrabook                13.3
# ...           ...             ...        ...                 ...
# 1267         Dell   Inspiron 3567   Notebook                15.6
# 1277         Acer  Aspire ES1-531   Notebook                15.6
# 1281         Dell   Inspiron 3567   Notebook                15.6
# 1291         Acer  Aspire ES1-531   Notebook                15.6
# 1295         Dell   Inspiron 3567   Notebook                15.6
#
#                                   screen  \
# 0     IPS Panel Retina Display 2560x1600
# 1                               1440x900
# 2                      Full HD 1920x1080
# ...

# %%
laptops.loc[laptops["os_version"].isnull(), "os"].value_counts()
# Out:
# os
# No OS        66
# Linux        62
# Chrome OS    27
# macOS        13
# Android       2
# Name: count, dtype: int64

# %%
laptops.loc[laptops["os_version"].isnull(), "os_version"] = "not specified"

# %%
laptops.isnull().sum()
# Out:
# manufacturer          0
# model_name            0
# category              0
# screen_size_inches    0
# screen                0
# cpu                   0
# ram                   0
# storage               0
# gpu                   0
# os                    0
# os_version            0
# weight_kg             0
# price_euros           0
# gpu_company           0
# gpu_model             0
# cpu_company           0
# cpu_model             0
# dtype: int64

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...
